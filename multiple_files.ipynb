# %% [markdown]
# # Multiple files with `pandas`

# %%
import numpy as np
import pandas as pd
import matplotlib

# %% [markdown]
# ## Merge Practice

# %%
a_df = pd.DataFrame({
    'Country': ['Germany', 'France', 'Belgium', 'Finland'],
    'Population (M)': [82.8, 67.2, 11.4, 5.5],
    'Capital': ['Berlin', 'Paris', 'Brussels', 'Helsinki']
})
a_df
# Out:
#    Country  Population (M)   Capital
# 0  Germany            82.8    Berlin
# 1   France            67.2     Paris
# 2  Belgium            11.4  Brussels
# 3  Finland             5.5  Helsinki

# %%
b_df = pd.DataFrame({
    'Country': ['Germany', 'France', 'Belgium', 'Canada'],
    'HDI': [0.936, 0.901, 0.916, 0.926]
})
b_df
# Out:
#    Country    HDI
# 0  Germany  0.936
# 1   France  0.901
# 2  Belgium  0.916
# 3   Canada  0.926

# %% [markdown]
# ### Inner Merge Practice

# %%
inner_merged_df=a_df.merge(b_df,left_on='Country', right_on='Country')
inner_merged_df
# Out:
#    Country  Population (M)   Capital    HDI
# 0  Germany            82.8    Berlin  0.936
# 1   France            67.2     Paris  0.901
# 2  Belgium            11.4  Brussels  0.916

# %% [markdown]
# #### Check your code

# %%
from nbresult import ChallengeResult

result = ChallengeResult('inner_merge',
    inner_merged_shape=inner_merged_df.shape,
    inner_merged_nulls=sum(inner_merged_df.isnull().sum())
)
result.write()

print(result.check())
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.10.6, pytest-7.1.3, pluggy-1.0.0 -- /home/ana/.pyenv/versions/lewagon/bin/python3
# cachedir: .pytest_cache
# rootdir: /home/ana/code/nusero92/data-multiple-files-with-pandas/tests
# plugins: anyio-3.6.2, asyncio-0.19.0
# asyncio: mode=strict
# collecting ... collected 2 items
#
# test_inner_merge.py::TestInnerMerge::test_inner_merged_nulls PASSED      [ 50%]
# test_inner_merge.py::TestInnerMerge::test_inner_merged_shape PASSED      [100%]
#
# ============================== 2 passed in 0.02s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/inner_merge.pickle
#
# git commit -m 'Completed inner_merge step'
#
# git push origin master

# %% [markdown]
# ### Left Merge Practice

# %%
left_merged_df=a_df.merge(b_df,left_on='Country', right_on='Country', how="left")
left_merged_df
# Out:
#    Country  Population (M)   Capital    HDI
# 0  Germany            82.8    Berlin  0.936
# 1   France            67.2     Paris  0.901
# 2  Belgium            11.4  Brussels  0.916
# 3  Finland             5.5  Helsinki    NaN

# %% [markdown]
# #### Check your code

# %%
from nbresult import ChallengeResult

result = ChallengeResult('left_merge',
    left_merged_shape=left_merged_df.shape,
    left_merged_nulls=sum(left_merged_df.isnull().sum())
)
result.write()

print(result.check())
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.10.6, pytest-7.1.3, pluggy-1.0.0 -- /home/ana/.pyenv/versions/lewagon/bin/python3
# cachedir: .pytest_cache
# rootdir: /home/ana/code/nusero92/data-multiple-files-with-pandas/tests
# plugins: anyio-3.6.2, asyncio-0.19.0
# asyncio: mode=strict
# collecting ... collected 2 items
#
# test_left_merge.py::TestLeftMerge::test_left_merged_df_shape PASSED      [ 50%]
# test_left_merge.py::TestLeftMerge::test_left_merged_nulls PASSED         [100%]
#
# ============================== 2 passed in 0.04s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/left_merge.pickle
#
# git commit -m 'Completed left_merge step'
#
# git push origin master

# %% [markdown]
# ### Right Merge Practice

# %%
right_merged_df=a_df.merge(b_df,left_on='Country', right_on='Country', how="right" )
right_merged_df
# Out:
#    Country  Population (M)   Capital    HDI
# 0  Germany            82.8    Berlin  0.936
# 1   France            67.2     Paris  0.901
# 2  Belgium            11.4  Brussels  0.916
# 3   Canada             NaN       NaN  0.926

# %% [markdown]
# #### Check your code

# %%
from nbresult import ChallengeResult

result = ChallengeResult('right_merge',
    right_merged_shape=right_merged_df.shape,
    right_merged_nulls=sum(right_merged_df.isnull().sum())
)
result.write()

print(result.check())
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.10.6, pytest-7.1.3, pluggy-1.0.0 -- /home/ana/.pyenv/versions/lewagon/bin/python3
# cachedir: .pytest_cache
# rootdir: /home/ana/code/nusero92/data-multiple-files-with-pandas/tests
# plugins: anyio-3.6.2, asyncio-0.19.0
# asyncio: mode=strict
# collecting ... collected 2 items
#
# test_right_merge.py::TestRightMerge::test_right_merged_df_shape PASSED   [ 50%]
# test_right_merge.py::TestRightMerge::test_right_merged_nulls PASSED      [100%]
#
# ============================== 2 passed in 0.03s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/right_merge.pickle
#
# git commit -m 'Completed right_merge step'
#
# git push origin master

# %% [markdown]
# ### Outer Merge Practice

# %%
outer_merged_df=a_df.merge(b_df,left_on='Country', right_on='Country', how="outer" )

# %%
outer_merged_df
# Out:
#    Country  Population (M)   Capital    HDI
# 0  Germany            82.8    Berlin  0.936
# 1   France            67.2     Paris  0.901
# 2  Belgium            11.4  Brussels  0.916
# 3  Finland             5.5  Helsinki    NaN
# 4   Canada             NaN       NaN  0.926

# %% [markdown]
# #### Check your code

# %%
from nbresult import ChallengeResult

result = ChallengeResult('outer_merge',
    outer_merged_shape=outer_merged_df.shape,
    outer_merged_nulls=sum(outer_merged_df.isnull().sum())
)
result.write()

print(result.check())
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.10.6, pytest-7.1.3, pluggy-1.0.0 -- /home/ana/.pyenv/versions/lewagon/bin/python3
# cachedir: .pytest_cache
# rootdir: /home/ana/code/nusero92/data-multiple-files-with-pandas/tests
# plugins: anyio-3.6.2, asyncio-0.19.0
# asyncio: mode=strict
# collecting ... collected 2 items
#
# test_outer_merge.py::TestOuterMerge::test_outer_merged_df_shape PASSED   [ 50%]
# test_outer_merge.py::TestOuterMerge::test_outer_merged_nulls PASSED      [100%]
#
# ============================== 2 passed in 0.04s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/outer_merge.pickle
#
# git commit -m 'Completed outer_merge step'
#
# git push origin master

# %% [markdown]
# ## Join Practice

# %%
aa_df = a_df.set_index("Country")
aa_df
# Out:
#          Population (M)   Capital
# Country
# Germany            82.8    Berlin
# France             67.2     Paris
# Belgium            11.4  Brussels
# Finland             5.5  Helsinki

# %%
bb_df = b_df.set_index("Country")
bb_df
# Out:
#            HDI
# Country
# Germany  0.936
# France   0.901
# Belgium  0.916
# Canada   0.926

# %%
aa_df.join(bb_df) #this is left join by default
# Out:
#          Population (M)   Capital    HDI
# Country
# Germany            82.8    Berlin  0.936
# France             67.2     Paris  0.901
# Belgium            11.4  Brussels  0.916
# Finland             5.5  Helsinki    NaN

# %%
aa_df.join(bb_df, how='inner')
# Out:
#          Population (M)   Capital    HDI
# Country
# Germany            82.8    Berlin  0.936
# France             67.2     Paris  0.901
# Belgium            11.4  Brussels  0.916

# %%
aa_df.join(bb_df, how='right')
# Out:
#          Population (M)   Capital    HDI
# Country
# Germany            82.8    Berlin  0.936
# France             67.2     Paris  0.901
# Belgium            11.4  Brussels  0.916
# Canada              NaN       NaN  0.926

# %%
aa_df.join(bb_df, how='outer')
# Out:
#          Population (M)   Capital    HDI
# Country
# Belgium            11.4  Brussels  0.916
# Canada              NaN       NaN  0.926
# Finland             5.5  Helsinki    NaN
# France             67.2     Paris  0.901
# Germany            82.8    Berlin  0.936

# %% [markdown]
# You can use .merge() when you want to merge based on a given column and .join() when you want to join on the index.

# %% [markdown]
# ## Concat Practice

# %%
concat_df = pd.concat([a_df, b_df], axis="index")
concat_df
# Out:
#    Country  Population (M)   Capital    HDI
# 0  Germany            82.8    Berlin    NaN
# 1   France            67.2     Paris    NaN
# 2  Belgium            11.4  Brussels    NaN
# 3  Finland             5.5  Helsinki    NaN
# 0  Germany             NaN       NaN  0.936
# 1   France             NaN       NaN  0.901
# 2  Belgium             NaN       NaN  0.916
# 3   Canada             NaN       NaN  0.926

# %% [markdown]
# ## Olympic Sports and Medals, 1896-2014

# %%
file ="dictionary.csv"
countries_df=pd.read_csv(file,decimal=",")
countries_df.head()
# Out:
#            Country Code  Population    GDP per Capita
# 0      Afghanistan  AFG  32526562.0  594.323081219966
# 1          Albania  ALB   2889167.0  3945.21758150914
# 2          Algeria  ALG  39666519.0  4206.03123244958
# 3  American Samoa*  ASA     55538.0               NaN
# 4          Andorra  AND     70473.0               NaN

# %%
file="summer.csv"
summer_df=pd.read_csv(file, decimal=",")
summer_df.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
file="winter.csv"
winter_df=pd.read_csv(file, decimal=",")
winter_df.head()
# Out:
#    Year      City     Sport Discipline               Athlete Country Gender  \
# 0  1924  Chamonix  Biathlon   Biathlon           BERTHET, G.     FRA    Men
# 1  1924  Chamonix  Biathlon   Biathlon        MANDRILLON, C.     FRA    Men
# 2  1924  Chamonix  Biathlon   Biathlon   MANDRILLON, Maurice     FRA    Men
# 3  1924  Chamonix  Biathlon   Biathlon       VANDELLE, André     FRA    Men
# 4  1924  Chamonix  Biathlon   Biathlon  AUFDENBLATTEN, Adolf     SUI    Men
#
#              Event   Medal
# 0  Military Patrol  Bronze
# 1  Military Patrol  Bronze
# 2  Military Patrol  Bronze
# 3  Military Patrol  Bronze
# 4  Military Patrol    Gold

# %% [markdown]
# ### Combining The Data

# %%
summer_df=summer_df.rename(columns={"Country":"Code"})
summer_df.head()
# Out:
#    Year    City     Sport Discipline             Athlete Code Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
winter_df=winter_df.rename(columns={"Country":"Code"})
winter_df.head()
# Out:
#    Year      City     Sport Discipline               Athlete Code Gender  \
# 0  1924  Chamonix  Biathlon   Biathlon           BERTHET, G.  FRA    Men
# 1  1924  Chamonix  Biathlon   Biathlon        MANDRILLON, C.  FRA    Men
# 2  1924  Chamonix  Biathlon   Biathlon   MANDRILLON, Maurice  FRA    Men
# 3  1924  Chamonix  Biathlon   Biathlon       VANDELLE, André  FRA    Men
# 4  1924  Chamonix  Biathlon   Biathlon  AUFDENBLATTEN, Adolf  SUI    Men
#
#              Event   Medal
# 0  Military Patrol  Bronze
# 1  Military Patrol  Bronze
# 2  Military Patrol  Bronze
# 3  Military Patrol  Bronze
# 4  Military Patrol    Gold

# %%
summer_countries_df=countries_df.merge(summer_df,left_on='Code', right_on='Code')
summer_countries_df.head()
# Out:
#        Country Code  Population    GDP per Capita  Year         City  \
# 0  Afghanistan  AFG  32526562.0  594.323081219966  2008      Beijing
# 1  Afghanistan  AFG  32526562.0  594.323081219966  2012       London
# 2      Algeria  ALG  39666519.0  4206.03123244958  1984  Los Angeles
# 3      Algeria  ALG  39666519.0  4206.03123244958  1984  Los Angeles
# 4      Algeria  ALG  39666519.0  4206.03123244958  1992    Barcelona
#
#        Sport Discipline             Athlete Gender  \
# 0  Taekwondo  Taekwondo    NIKPAI, Rohullah    Men
# 1  Taekwondo  Taekwondo    NIKPAI, Rohullah    Men
# 2     Boxing     Boxing      ZAOUI, Mohamed    Men
# 3     Boxing     Boxing    MOUSSA, Mustapha    Men
# 4  Athletics  Athletics  BOULMERKA, Hassiba  Women
#
#                            Event   Medal
# 0                        - 58 KG  Bronze
# 1                     58 - 68 KG  Bronze
# 2                        71-75KG  Bronze
# 3  75 - 81KG (Light-Heavyweight)  Bronze
# 4                          1500M    Gold

# %%
summer_countries_df["Season"]="summer"
summer_countries_df
# Out:
#            Country Code  Population    GDP per Capita  Year         City  \
# 0      Afghanistan  AFG  32526562.0  594.323081219966  2008      Beijing
# 1      Afghanistan  AFG  32526562.0  594.323081219966  2012       London
# 2          Algeria  ALG  39666519.0  4206.03123244958  1984  Los Angeles
# 3          Algeria  ALG  39666519.0  4206.03123244958  1984  Los Angeles
# 4          Algeria  ALG  39666519.0  4206.03123244958  1992    Barcelona
# ...            ...  ...         ...               ...   ...          ...
# 25737     Zimbabwe  ZIM  15602751.0  924.143819253412  2004       Athens
# 25738     Zimbabwe  ZIM  15602751.0  924.143819253412  2008      Beijing
# 25739     Zimbabwe  ZIM  15602751.0  924.143819253412  2008      Beijing
# 25740     Zimbabwe  ZIM  15602751.0  924.143819253412  2008      Beijing
# 25741     Zimbabwe  ZIM  15602751.0  924.143819253412  2008      Beijing
#
#            Sport Discipline             Athlete Gender  \
# 0      Taekwondo  Taekwondo    NIKPAI, Rohullah    Men
# 1      Taekwondo  Taekwondo    NIKPAI, Rohullah    Men
# 2         Boxing     Boxing      ZAOUI, Mohamed    Men
# 3         Boxing     Boxing    MOUSSA, Mustapha    Men
# 4      Athletics  Athletics  BOULMERKA, Hassiba  Women
# ...          ...        ...                 ...    ...
# 25737   Aquatics   Swimming    COVENTRY, Kirsty  Women
# 25738   Aquatics   Swimming    COVENTRY, Kirsty  Women
# 25739   Aquatics   Swimming    COVENTRY, Kirsty  Women
# 25740   Aquatics   Swimming    COVENTRY, Kirsty  Women
# 25741   Aquatics   Swimming    COVENTRY, Kirsty  Women
#
#                                Event   Medal  Season
# 0                            - 58 KG  Bronze  summer
# 1                         58 - 68 KG  Bronze  summer
# 2                            71-75KG  Bronze  summer
# 3      75 - 81KG (Light-Heavyweight)  Bronze  summer
# 4                              1500M    Gold  summer
# ...                              ...     ...     ...
# 25737         200M Individual Medley  Bronze  summer
# 25738                100M Backstroke  Silver  summer
# 25739                200M Backstroke    Gold  summer
# 25740         200M Individual Medley  Silver  summer
# 25741         400M Individual Medley  Silver  summer
#
# [25742 rows x 13 columns]

# %%
winter_countries_df=countries_df.merge(winter_df,left_on='Code', right_on='Code')
winter_countries_df.head()
# Out:
#      Country Code  Population    GDP per Capita  Year         City    Sport  \
# 0  Australia  AUS  23781169.0  56310.9629933721  1994  Lillehammer  Skating
# 1  Australia  AUS  23781169.0  56310.9629933721  1994  Lillehammer  Skating
# 2  Australia  AUS  23781169.0  56310.9629933721  1994  Lillehammer  Skating
# 3  Australia  AUS  23781169.0  56310.9629933721  1994  Lillehammer  Skating
# 4  Australia  AUS  23781169.0  56310.9629933721  1998       Nagano   Skiing
#
#                   Discipline             Athlete Gender        Event   Medal
# 0  Short Track Speed Skating    BRADBURY, Steven    Men  5000M Relay  Bronze
# 1  Short Track Speed Skating      HANSEN, Kieran    Men  5000M Relay  Bronze
# 2  Short Track Speed Skating      MURTHA, Andrew    Men  5000M Relay  Bronze
# 3  Short Track Speed Skating  NIZIELSKI, Richard    Men  5000M Relay  Bronze
# 4              Alpine Skiing      STEGGALL, Zali  Women       Slalom  Bronze

# %%
winter_countries_df["Season"]="winter"
winter_countries_df
# Out:
#             Country Code   Population    GDP per Capita  Year         City  \
# 0         Australia  AUS   23781169.0  56310.9629933721  1994  Lillehammer
# 1         Australia  AUS   23781169.0  56310.9629933721  1994  Lillehammer
# 2         Australia  AUS   23781169.0  56310.9629933721  1994  Lillehammer
# 3         Australia  AUS   23781169.0  56310.9629933721  1994  Lillehammer
# 4         Australia  AUS   23781169.0  56310.9629933721  1998       Nagano
# ...             ...  ...          ...               ...   ...          ...
# 4821  United States  USA  321418820.0  56115.7184261955  2014        Sochi
# 4822  United States  USA  321418820.0  56115.7184261955  2014        Sochi
# 4823  United States  USA  321418820.0  56115.7184261955  2014        Sochi
# 4824  United States  USA  321418820.0  56115.7184261955  2014        Sochi
# 4825     Uzbekistan  UZB   31299500.0  2132.07036847857  1994  Lillehammer
#
#         Sport                 Discipline              Athlete Gender  \
# 0     Skating  Short Track Speed Skating     BRADBURY, Steven    Men
# 1     Skating  Short Track Speed Skating       HANSEN, Kieran    Men
# 2     Skating  Short Track Speed Skating       MURTHA, Andrew    Men
# 3     Skating  Short Track Speed Skating   NIZIELSKI, Richard    Men
# 4      Skiing              Alpine Skiing       STEGGALL, Zali  Women
# ...       ...                        ...                  ...    ...
# 4821   Skiing                  Snowboard        DEIBOLD, Alex    Men
# 4822   Skiing                  Snowboard         CLARK, Kelly  Women
# 4823   Skiing                  Snowboard  FARRINGTON, Kaitlyn  Women
# 4824   Skiing                  Snowboard      ANDERSON, Jamie  Women
# 4825   Skiing           Freestyle Skiing     CHERYAZOVA, Lina  Women
#
#                 Event   Medal  Season
# 0         5000M Relay  Bronze  winter
# 1         5000M Relay  Bronze  winter
# 2         5000M Relay  Bronze  winter
# 3         5000M Relay  Bronze  winter
# 4              Slalom  Bronze  winter
# ...               ...     ...     ...
# 4821  Snowboard Cross  Bronze  winter
# 4822        Half-Pipe  Bronze  winter
# 4823        Half-Pipe    Gold  winter
# 4824       Slopestyle    Gold  winter
# 4825          Aerials    Gold  winter
#
# [4826 rows x 13 columns]

# %%
all_df=pd.concat([summer_countries_df,winter_countries_df])
all_df
# Out:
#             Country Code   Population    GDP per Capita  Year         City  \
# 0       Afghanistan  AFG   32526562.0  594.323081219966  2008      Beijing
# 1       Afghanistan  AFG   32526562.0  594.323081219966  2012       London
# 2           Algeria  ALG   39666519.0  4206.03123244958  1984  Los Angeles
# 3           Algeria  ALG   39666519.0  4206.03123244958  1984  Los Angeles
# 4           Algeria  ALG   39666519.0  4206.03123244958  1992    Barcelona
# ...             ...  ...          ...               ...   ...          ...
# 4821  United States  USA  321418820.0  56115.7184261955  2014        Sochi
# 4822  United States  USA  321418820.0  56115.7184261955  2014        Sochi
# 4823  United States  USA  321418820.0  56115.7184261955  2014        Sochi
# 4824  United States  USA  321418820.0  56115.7184261955  2014        Sochi
# 4825     Uzbekistan  UZB   31299500.0  2132.07036847857  1994  Lillehammer
#
#           Sport        Discipline              Athlete Gender  \
# 0     Taekwondo         Taekwondo     NIKPAI, Rohullah    Men
# 1     Taekwondo         Taekwondo     NIKPAI, Rohullah    Men
# 2        Boxing            Boxing       ZAOUI, Mohamed    Men
# 3        Boxing            Boxing     MOUSSA, Mustapha    Men
# 4     Athletics         Athletics   BOULMERKA, Hassiba  Women
# ...         ...               ...                  ...    ...
# 4821     Skiing         Snowboard        DEIBOLD, Alex    Men
# 4822     Skiing         Snowboard         CLARK, Kelly  Women
# 4823     Skiing         Snowboard  FARRINGTON, Kaitlyn  Women
# 4824     Skiing         Snowboard      ANDERSON, Jamie  Women
# 4825     Skiing  Freestyle Skiing     CHERYAZOVA, Lina  Women
#
#                               Event   Medal  Season
# 0                           - 58 KG  Bronze  summer
# 1                        58 - 68 KG  Bronze  summer
# 2                           71-75KG  Bronze  summer
# 3     75 - 81KG (Light-Heavyweight)  Bronze  summer
# 4                             1500M    Gold  summer
# ...                             ...     ...     ...
# 4821                Snowboard Cross  Bronze  winter
# 4822                      Half-Pipe  Bronze  winter
# 4823                      Half-Pipe    Gold  winter
# 4824                     Slopestyle    Gold  winter
# 4825                        Aerials    Gold  winter
#
# [30568 rows x 13 columns]

# %% [markdown]
# #### Check your code

# %%
from nbresult import ChallengeResult

result = ChallengeResult('all_df',
    all_df_shape=all_df.shape,
    all_df_columns=set(all_df.columns)
)
result.write()

print(result.check())
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.10.6, pytest-7.1.3, pluggy-1.0.0 -- /home/ana/.pyenv/versions/lewagon/bin/python3
# cachedir: .pytest_cache
# rootdir: /home/ana/code/nusero92/data-multiple-files-with-pandas/tests
# plugins: anyio-3.6.2, asyncio-0.19.0
# asyncio: mode=strict
# collecting ... collected 2 items
#
# test_all_df.py::TestAllDf::test_all_df_columns PASSED                    [ 50%]
# test_all_df.py::TestAllDf::test_all_df_shape PASSED                      [100%]
#
# ============================== 2 passed in 0.02s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/all_df.pickle
#
# git commit -m 'Completed all_df step'
#
# git push origin master

# %% [markdown]
# ### Top Countries Analysis

# %%
=all_df[all_df["Year"] > 1984]
type(country)
# Out:
# pandas.core.frame.DataFrame

# %%
sort=country[["Medal"]].sum()
sort
# Out:
# Medal    BronzeBronzeGoldBronzeGoldGoldBronzeGoldSilver...
# dtype: object
